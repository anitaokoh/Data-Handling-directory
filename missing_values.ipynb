# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np

# %%
import random

# %% [markdown]
# # Generating the dataset

# %%
np.random.seed(0)
degree_option = ['Bachelor', 'Masters', 'No Degree']
age_option = [18, 25, 30]
degree = []
age = []
for i in range(0, 10):
    s = np.random.choice(degree_option)
    y = np.random.choice(age_option)
    degree.append(s)
    age.append(y)
    
for i in range(0,2):
    s = np.random.choice(list(range(0,7)),replace=False)
    y = np.random.choice(list(range(3,10)),replace=False)
    degree[s]= np.nan
    age[y] = np.nan

# %% [markdown]
# # Creating a dataframe and adding other columns

# %%
df = pd.DataFrame(np.array([degree,age]).T, columns=['Degree', 'Age'])

# %%
df['Degree'] = np.where(df['Degree']== 'nan', np.nan, df['Degree'])
df['Age'] = np.where(df['Age']== 'nan', np.nan, df['Age'])

df.insert(0,'city', [np.random.choice(['Berlin', 'Madrid', 'Lisbon']) for i in range(0,10)])
df['Salary'] = ['45,000'] + [np.nan for i in range(0,9)]
df['married'] = [np.random.choice([1,0]) for i in range(0,10)]

# %%
df
# Out:
#      city     Degree  Age  Salary  married
# 0  Lisbon        NaN   25  45,000        0
# 1  Berlin   Bachelor   25     NaN        1
# 2  Lisbon        NaN   30     NaN        1
# 3  Lisbon   Bachelor   30     NaN        1
# 4  Berlin   Bachelor   18     NaN        0
# 5  Lisbon   Bachelor  NaN     NaN        0
# 6  Berlin    Masters   30     NaN        1
# 7  Berlin  No Degree  NaN     NaN        0
# 8  Berlin    Masters   25     NaN        1
# 9  Madrid    Masters   25     NaN        1

# %% [markdown]
# ## Creating Variations of the dataframe

# %%
df_example1 = df.drop('Salary', axis=1)
df_example2 =  df.drop(['Degree', 'Age'], axis=1)
df_example3 =  df.drop(['Degree','Salary'], axis=1)
df_example4 =  df.drop(['Age','Salary'], axis=1)

# %% [markdown]
# # Imputation methods
# ### For removing rows

# %%
df_example1
# Out:
#      city     Degree  Age  married
# 0  Lisbon        NaN   25        0
# 1  Berlin   Bachelor   25        1
# 2  Lisbon        NaN   30        1
# 3  Lisbon   Bachelor   30        1
# 4  Berlin   Bachelor   18        0
# 5  Lisbon   Bachelor  NaN        0
# 6  Berlin    Masters   30        1
# 7  Berlin  No Degree  NaN        0
# 8  Berlin    Masters   25        1
# 9  Madrid    Masters   25        1

# %%
remove_rows = df_example1.dropna(axis=0)

# %%
remove_rows
# Out:
#      city    Degree Age  married
# 1  Berlin  Bachelor  25        1
# 3  Lisbon  Bachelor  30        1
# 4  Berlin  Bachelor  18        0
# 6  Berlin   Masters  30        1
# 8  Berlin   Masters  25        1
# 9  Madrid   Masters  25        1

# %% [markdown]
# ### For removing columns

# %%
df_example2
# Out:
#      city  Salary  married
# 0  Lisbon  45,000        0
# 1  Berlin     NaN        1
# 2  Lisbon     NaN        1
# 3  Lisbon     NaN        1
# 4  Berlin     NaN        0
# 5  Lisbon     NaN        0
# 6  Berlin     NaN        1
# 7  Berlin     NaN        0
# 8  Berlin     NaN        1
# 9  Madrid     NaN        1

# %%
remove_column = df_example2.drop('Salary', axis=1)

# %%
remove_column
# Out:
#      city  married
# 0  Lisbon        0
# 1  Berlin        1
# 2  Lisbon        1
# 3  Lisbon        1
# 4  Berlin        0
# 5  Lisbon        0
# 6  Berlin        1
# 7  Berlin        0
# 8  Berlin        1
# 9  Madrid        1

# %% [markdown]
# ### Mean Imputation

# %%
df_example3
# Out:
#      city  Age  married
# 0  Lisbon   25        0
# 1  Berlin   25        1
# 2  Lisbon   30        1
# 3  Lisbon   30        1
# 4  Berlin   18        0
# 5  Lisbon  NaN        0
# 6  Berlin   30        1
# 7  Berlin  NaN        0
# 8  Berlin   25        1
# 9  Madrid   25        1

# %%
age_mean = df_example3['Age'].astype(float).mean()
df_example3['Age'] = df_example3['Age'].fillna(age_mean)

# %%
age_mean
# Out:
# 26.0

# %%
df_example3
# Out:
#      city Age  married
# 0  Lisbon  25        0
# 1  Berlin  25        1
# 2  Lisbon  30        1
# 3  Lisbon  30        1
# 4  Berlin  18        0
# 5  Lisbon  26        0
# 6  Berlin  30        1
# 7  Berlin  26        0
# 8  Berlin  25        1
# 9  Madrid  25        1

# %% [markdown]
# ### Mode Imputation

# %%
df_example4
# Out:
#      city     Degree  married
# 0  Lisbon        NaN        0
# 1  Berlin   Bachelor        1
# 2  Lisbon        NaN        1
# 3  Lisbon   Bachelor        1
# 4  Berlin   Bachelor        0
# 5  Lisbon   Bachelor        0
# 6  Berlin    Masters        1
# 7  Berlin  No Degree        0
# 8  Berlin    Masters        1
# 9  Madrid    Masters        1

# %%
degree_mode = df_example4['Degree'].mode()
df_example4['Degree'] = df_example4['Degree'].fillna(degree_mode[0])

# %%
df_example4
# Out:
#      city     Degree  married
# 0  Lisbon   Bachelor        0
# 1  Berlin   Bachelor        1
# 2  Lisbon   Bachelor        1
# 3  Lisbon   Bachelor        1
# 4  Berlin   Bachelor        0
# 5  Lisbon   Bachelor        0
# 6  Berlin    Masters        1
# 7  Berlin  No Degree        0
# 8  Berlin    Masters        1
# 9  Madrid    Masters        1

# %% [markdown]
# ### Random sampling Imputation

# %%
df_example5 = df_example4.copy().drop('Degree', axis=1)
df_example5.insert(1, 'Age', df['Age'])

# %%
df_example5
# Out:
#      city  Age  married
# 0  Lisbon   25        0
# 1  Berlin   25        1
# 2  Lisbon   30        1
# 3  Lisbon   30        1
# 4  Berlin   18        0
# 5  Lisbon  NaN        0
# 6  Berlin   30        1
# 7  Berlin  NaN        0
# 8  Berlin   25        1
# 9  Madrid   25        1

# %%
# df_example5['age_impute'] = df_example5['Age'].copy()
df_example5.insert(2, 'age_impute', df['Age'])
random_sample = df_example5['Age'].dropna().sample(
    df_example5['Age'].isnull().sum(), random_state=0)

# %%
random_sample
# Out:
# 8    25
# 2    30
# Name: Age, dtype: object

# %%
random_sample.index = df_example5[df_example5['Age'].isnull()].index

# %%
random_sample
# Out:
# 5    25
# 7    30
# Name: Age, dtype: object

# %%
df_example5.loc[df_example5['Age'].isnull(), 'age_impute'] = random_sample

# %%
df_example5
# Out:
#      city  Age age_impute  married
# 0  Lisbon   25         25        0
# 1  Berlin   25         25        1
# 2  Lisbon   30         30        1
# 3  Lisbon   30         30        1
# 4  Berlin   18         18        0
# 5  Lisbon  NaN         25        0
# 6  Berlin   30         30        1
# 7  Berlin  NaN         30        0
# 8  Berlin   25         25        1
# 9  Madrid   25         25        1

# %% [markdown]
# ### Arbitrary Values Imputation

# %%
df_example6 =  df.drop(['Degree','Salary'], axis=1)
df_example6
# Out:
#      city  Age  married
# 0  Lisbon   25        0
# 1  Berlin   25        1
# 2  Lisbon   30        1
# 3  Lisbon   30        1
# 4  Berlin   18        0
# 5  Lisbon  NaN        0
# 6  Berlin   30        1
# 7  Berlin  NaN        0
# 8  Berlin   25        1
# 9  Madrid   25        1

# %%
df_example6['Age'] = df_example6['Age'].fillna(-1)
df_example6
# Out:
#      city Age  married
# 0  Lisbon  25        0
# 1  Berlin  25        1
# 2  Lisbon  30        1
# 3  Lisbon  30        1
# 4  Berlin  18        0
# 5  Lisbon  -1        0
# 6  Berlin  30        1
# 7  Berlin  -1        0
# 8  Berlin  25        1
# 9  Madrid  25        1

# %% [markdown]
# ### Missing Category Imputation

# %%
df_example7 =  df.drop(['Age','Salary'], axis=1)
df_example7
# Out:
#      city     Degree  married
# 0  Lisbon        NaN        0
# 1  Berlin   Bachelor        1
# 2  Lisbon        NaN        1
# 3  Lisbon   Bachelor        1
# 4  Berlin   Bachelor        0
# 5  Lisbon   Bachelor        0
# 6  Berlin    Masters        1
# 7  Berlin  No Degree        0
# 8  Berlin    Masters        1
# 9  Madrid    Masters        1

# %%
df_example7['Degree'] = df_example7['Degree'].fillna('Missing')
df_example7
# Out:
#      city     Degree  married
# 0  Lisbon    Missing        0
# 1  Berlin   Bachelor        1
# 2  Lisbon    Missing        1
# 3  Lisbon   Bachelor        1
# 4  Berlin   Bachelor        0
# 5  Lisbon   Bachelor        0
# 6  Berlin    Masters        1
# 7  Berlin  No Degree        0
# 8  Berlin    Masters        1
# 9  Madrid    Masters        1

# %% [markdown]
# ### Missing Indicator Method

# %%
df_example8 =  df.drop(['Age','Salary'], axis=1)
df_example8
# Out:
#      city     Degree  married
# 0  Lisbon        NaN        0
# 1  Berlin   Bachelor        1
# 2  Lisbon        NaN        1
# 3  Lisbon   Bachelor        1
# 4  Berlin   Bachelor        0
# 5  Lisbon   Bachelor        0
# 6  Berlin    Masters        1
# 7  Berlin  No Degree        0
# 8  Berlin    Masters        1
# 9  Madrid    Masters        1

# %%
df_example8.insert(2, 'Degree_indicator',(np.where(df_example8['Degree'].isna(), 1, 0)) )
df_example8['Degree'] = df_example8['Degree'].fillna(degree_mode[0])

# %%
df_example8
# Out:
#      city     Degree  Degree_indicator  married
# 0  Lisbon   Bachelor                 1        0
# 1  Berlin   Bachelor                 0        1
# 2  Lisbon   Bachelor                 1        1
# 3  Lisbon   Bachelor                 0        1
# 4  Berlin   Bachelor                 0        0
# 5  Lisbon   Bachelor                 0        0
# 6  Berlin    Masters                 0        1
# 7  Berlin  No Degree                 0        0
# 8  Berlin    Masters                 0        1
# 9  Madrid    Masters                 0        1
